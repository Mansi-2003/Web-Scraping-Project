# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
website = 'https://www.cars24.com/buy-used-toyota-cars-delhi-ncr/?sort=bestmatch&serveWarrantyCount=true&storeCityId=1'

# %%
response = requests.get(website)

# %%
response
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><link href="https://assets.cars24.com" rel="preconnect"/><link href="https://media.cars24.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://analytics.twitter.com" rel="preconnect"/><link href="https://www.facebook.com" rel="preconnect"/><link href="https://www.google.com" rel="preconnect"/><link href="https://www.google.co.in" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://t.co" rel="preconnect"/><link href="https://static.ads-twitter.com" rel="preconnect"/><link href="https://tracking.cars24.com" rel="preconnect"/><link href="https://gumi.criteo.com" rel="preconnect"/><link href="https://dynamic.criteo.com" rel="preconnect"/><link href="https://tr.snapchat.com" rel="preconnect"/><link href="https://pixel.tapad.com" rel="preconnect"/><link href="https://sslwidget.criteo.com" rel="preconnect"/><meta content="width=device-width, initial-scale=1, maximum-scale=5, user-scalable=yes" name="viewport"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/73be653317b9a76e.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/2f11d4392d92563e.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/b98d53648bd4e16d.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/d01b57df219a7730.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/b19660e63a6d2cf4.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/2d4ac01faae9631a.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/1cbdb1e1a495634e.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/427523acd3d771f7.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/f349509ec6c23a5f.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/11296da54b128758.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/0db3c9b1be12ae8c.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/e64d5f002ef07a72.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/480c2299d6e9f3d6.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/08eed280d85004d9.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/4d70946f48a75205.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/6ccd95cb4675b53b.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/ac8e1f3e6714eea4.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/b7d69c504feb4d3e.css" ...
# .cyPhJl{font-size:var(--font-size-250);font-weight:var(--semibold);line-height:var(--line-height-250);color:var(--grey-900);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .AgQbP{font-size:var(--font-size-200);font-weight:var(--medium);line-height:var(--line-height-200);color:var(--grey-900);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .dughoY{font-size:var(--font-size-200);font-weight:var(--regular);line-height:var(--line-height-200);color:var(--grey-900);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .dDkhIL{font-size:var(--font-size-150);font-weight:var(--medium);line-height:var(--line-height-150);color:var(--grey-900);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .lmmumg{font-size:var(--font-size-150);font-weight:var(--regular);line-height:var(--line-height-150);color:var(--grey-500);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .kjFjan{font-size:var(--font-size-250);font-weight:var(--medium);line-height:var(--line-height-250);color:var(--grey-900);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .fccwQo{font-size:var(--font-size-200);font-weight:var(--regular);line-height:var(--line-height-200);color:var(--grey-500);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .kvfdZL{font-size:var(--font-size-150);font-weight:var(--medium);line-height:var(--line-height-150);color:var(--grey-500);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# .gbxhkm{font-size:var(--font-size-200);font-weight:var(--regular);line-height:var(--line-height-200);color:var(--grey-500);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:line-through;}/*!sc*/
# .eQRKIA{font-size:var(--font-size-150);font-weight:var(--semibold);line-height:var(--line-height-150);color:var(--orange-500);margin:0;padding:0;text-align:left;text-transform:none;text-decoration:none;}/*!sc*/
# data-styled.g1[id="sc-braxZu"]{content:"jEqeKQ,cyPhJl,AgQbP,dughoY,dDkhIL,lmmumg,kjFjan,fccwQo,kvfdZL,gbxhkm,eQRKIA,"}/*!sc*/
# .dLsbSw{color:var(--orange-500)!important;text-decoration:none;text-decoration-style:dashed;cursor:pointer;display:flex;align-items:center;justify-content:center;gap:var(--spacing-4);transition:transform 0.2s,filter 0.3s;}/*!sc*/
# .dLsbSw:active{transform:scale(0.98);filter:brightness(80%);}/*!sc*/
# .dLsbSw p{font-size:var(--font-size-200);font-weight:var(--semibold);line-height:var(--line-height-200);border-bottom:none;margin:0;padding:0;}/*!sc*/
# .dLsbSw:hover{color:var(--orange-600)!important;}/*!sc*/
# .dLsbSw.disabled{color:var(--grey-300)!important;cursor:not-allowed;pointer-events:none;}/*!sc*/
# .jOCeuW{color:var(--grey-900)!important;text-decoration:none;text-decoration-style:dashed;cursor:pointer;display:flex;align-items:center;justify-content:center;gap:var(--spacing-4);transition:transform 0.2s,filter 0.3s;}/*!sc*/
# .jOCeuW:active{transform:scale(0.98);filter:brightness(80%);}/*!sc*/
# .jOCeuW p{font-size:var(--font-size-200);font-weight:var(--semibold);line-height:var(--line-height-200);border-bottom:1px dashed var(--grey-900);margin:0;padding:0;}/*!sc*/
# .jOCeuW:hover{color:var(--grey-900)!important;}/*!sc*/
# .jOCeuW.disabled{color:var(--grey-300)!important;cursor:not-allowed;pointer-events:none;}/*!sc*/
# .kYvReg{color:var(--grey-500)!important;text-decoration:none;text-decoration-style:dashed;cursor:pointer;display:flex;align-items:center;justify-content:center;gap:var(--spacing-4);transition:transform 0.2s,filter 0.3s;}/*!sc*/
# .kYvReg:active{transform:scale(0.98);filter:brightness(80%);}/*!sc*/
# .kYvReg p{font-size:var(--font-size-150);font-weight:var(--medium);line-height:var(--line-height-150);border-bottom:1px dashed var(--grey-500);margin:0;padding:0;}/*!sc*/
# .kYvReg:hover{color:var(--grey-500)!important;}/*!sc*/
# .kYvReg.disabled{color:var(--grey-300)!important;cursor:not-allowed;pointer-events:none;}/*!sc*/
# data-styled.g2[id="sc-gJhJTp"]{content:"dLsbSw,jOCeuW,kYvReg,"}/*!sc*/
# .gcwFm{font-size:var(--font-size-4xl);font-weight:var(--semibold);line-height:var(--font-line-height-5xl);color:var(--grey-900);margin:0;padding:0;}/*!sc*/
# .bswdIg{font-size:var(--font-size-3xl);font-weight:var(--semibold);line-height:var(--font-line-height-4xl);color:var(--grey-900);margin:0;padding:0;}/*!sc*/
# data-styled.g3[id="sc-elDIKY"]{content:"gcwFm,bswdIg,"}/*!sc*/
# .jhuTLR{display:block;font-size:var(--font-size-xs);font-weight:var(--semibold);line-height:var(--font-line-height-xs);text-decoration:none;color:var(--grey-900);margin:0;padding:0;text-transform:none;}/*!sc*/
# .lckVxw{display:block;font-size:var(--font-size-xs);font-weight:var(--regular);line-height:var(--font-line-height-xs);text-decoration:none;color:var(--grey-900);margin:0;padding:0;text-transform:none;}/*!sc*/
# .cAUaeA{display:block;font-size:var(--font-size-xs);font-weight:var(--semibold);line-height:var(--font-line-height-xs);text-decoration:none;color:var(--sky-blue-700);margin:0;padding:0;text-transform:none;}/*!sc*/
# .jTKVQa{display:block;font-size:var(--font-size-xs);font-weight:var(--regular);line-height:var(--font-line-height-xs);text-decoration:none;color:var(--grey-300);margin:0;padding:0;text-transform:none;}/*!sc*/
# .dMCGxA{display:block;font-size:var(--font-size-xs);font-weight:var(--semibold);line-height:var(--font-line-height-xs);text-decoration:none;margin:0;padding:0;text-transform:none;}/*!sc*/
# .giXNIM{display:block;font-size:var(--font-size-xs);font-weight:var(--regular);line-height:var(--font-line-height-xs);text-decoration:none;color:var(--grey-500);margin:0;padding:0;text-transform:none;}/*!sc*/
# data-styled.g4[id="sc-fQpRED"]{content:"jhuTLR,lckVxw,cAUaeA,jTKVQa,dMCGxA,giXNIM,"}/*!sc*/
# .dNCbuL{background-color:var(--base-white);border:none;color:var(--orange-500);padding:var(--spacing-16) var(--spacing-16);height:var(--size-32);outline:none;border-radius:var(--corner-radius-8);gap:8px;display:flex;align-items:center;justify-content:center;font-size:var(--font-size-200);line-height:var(--line-height-200);min-width:100px;font-weight:var(--semibold);width:100%;cursor:pointer;transition:transform 0.2s,filter 0.3s;}/*!sc*/
# .dNCbuL:hover,.dNCbuL:focus{background-color:var(--base-white);color:var(--orange-500);}/*!sc*/
# .dNCbuL:disabled{background-color:var(--grey-50);color:var(--grey-300);pointer-events:none;border:1px solid undefined;}/*!sc*/
# .dNCbuL:active{transform:scale(0.98);filter:brightness(80%);background-color:var(--grey-50);color:var(--orange-500);}/*!sc*/
# data-styled.g5[id="sc-dsLQwm"]{content:"dNCbuL,"}/*!sc*/
# .aszpy{font-size:var(--font-size-base);font-weight:var(--medium);line-height:var(--font-line-height-base);color:var(--grey-900);text-decoration:none;margin:0;padding:0;}/*!sc*/
# .iFeDQM{font-size:var(--font-size-lg);font-weight:var(--semibold);line-height:var(--font-line-height-lg);color:var(--grey-900);text-decoration:none;margin:0;padding:0;}/*!sc*/
# data-styled.g7[id="sc-gnpbhQ"]{content:"aszpy,iFeDQM,"}/*!sc*/
# .bsobfF{display:block;font-size:var(--font-size-sm);font-weight:var(--semibold);line-height:var(--font-line-height-lg);color:var(--orange-500);margin:0;padding:0;}/*!sc*/
# .dlfOhF{display:block;font-size:var(--font-size-sm);font-weight:var(--regular);line-height:var(--font-line-height-lg);color:var(--grey-900);margin:0;padding:0;}/*!sc*/
# .fvCLhQ{display:block;font-size:var(--font-size-sm);font-weight:var(--semibold);line-height:var(--font-line-height-lg);color:var(--grey-900);margin:0;padding:0;}/*!sc*/
# data-styled.g8[id="sc-la-DxNn"]{content:"bsobfF,dlfOhF,fvCLhQ,"}/*!sc*/
# .fuGeOF{height:16px;width:16px;fill:#EF6E0B;}/*!sc*/
# .cpDdLR{height:20px;width:20px;fill:#EF6E0B;}/*!sc*/
# .UsVQR{height:6px;width:6px;fill:#0059A3;}/*!sc*/
# .hBddAC{height:20px;width:20px;fill:none;}/*!sc*/
# .YfQgl{height:var(--icon-size-12);width:var(--icon-size-12);fill:#0059A3;}/*!sc*/
# data-styled.g9[id="sc-iCZwEW"]{content:"fuGeOF,cpDdLR,UsVQR,hBddAC,YfQgl,"}/*!sc*/
# .hIshdK{background-color:var(--grey-50);height:99px;width:90px;display:flex;align-items:center;justify-content:center;border-radius:var(--spacing-8);}/*!sc*/
# data-styled.g26[id="sc-gutikT"]{content:"hIshdK,"}/*!sc*/
# .dGSZFX{display:flex;flex-direction:column;align-items:center;text-decoration:none;}/*!sc*/
# data-styled.g28[id="sc-fLVwEd"]{content:"dGSZFX,"}/*!sc*/
# .lmxydK{margin-bottom:var(--spacing-12);}/*!sc*/
# data-styled.g29[id="sc-gLXSEc"]{content:"lmxydK,"}/*!sc*/
# .kXBsSf{display:flex;gap:var(--spacing-12);align-items:center;margin-bottom:var(--spacing-24);}/*!sc*/
# .kXBsSf span{color:var(--grey-250);}/*!sc*/
# @media (min-width: 767px){.kXBsSf{margin-bottom:var(--spacing-36);}}/*!sc*/
# data-styled.g51[id="sc-foMnoT"]{content:"kXBsSf,"}/*!sc*/
# .ihkNPc{font-size:var(--font-size-300);font-weight:var(--semibold);line-height:var(--line-height-300);margin:var(--spacing-0);}/*!sc*/
# data-styled.g52[id="sc-WChnI"]{content:"ihkNPc,"}/*!sc*/
# .bqXFys{padding:var(--spacing-24) var(--spacing-20);}/*!sc*/
# @media (min-width: 767px){.bqXFys{display:flex;flex-direction:column;align-items:center;}}/*!sc*/
# data-styled.g53[id="sc-flUsNl"]{content:"bqXFys,"}/*!sc*/
# .fkhvvQ{display:grid;grid-template-columns:repeat(2, 1fr);column-gap:var(--spacing-16);row-gap:var(--spacing-24);margin-bottom:var(--spacing-24);}/*!sc*/
# @media (min-width: 540px){.fkhvvQ{grid-template-columns:repeat(3, 1fr);column-gap:var(--spacing-24);}}/*!sc*/
# @media (min-width: 980px){.fkhvvQ{column-gap:80px;}}/*!sc*/
# data-styled.g54[id="sc-hAqmLS"]{content:"fkhvvQ,"}/*!sc*/
# .ksnOGz{height:auto;}/*!sc*/
# data-styled.g55[id="sc-AmOMz"]{content:"ksnOGz,"}/*!sc*/
# .kDQAKr{font-size:var(--font-size-300);font-weight:var(--semibold);line-height:var(--line-height-300);color:var(--grey-900);text-decoration:none;text-transform:uppercase;margin-bottom:var(--spacing-12);}/*!sc*/
# data-styled.g56[id="sc-hxyskk"]{content:"kDQAKr,"}/*!sc*/
# .bMuyws{margin-bottom:0;padding:0;display:flex;flex-direction:column;row-gap:var(--spacing-12);font-size:0;}/*!sc*/
# .bMuyws li a{font-size:var(--font-size-250);font-weight:var(--medium);line-height:var(--line-height-300);color:var(--grey-500);text-decoration:none;margin:0;padding:0;}/*!sc*/
# .bMuyws li a li:first-child{margin-top:var(--spacing-4);}/*!sc*/
# .bMuyws li a li:first-child li a:hover,.bMuyws li a li:first-child li a:focus,.bMuyws li a li:first-child li a:active{color:var(--grey-500);}/*!sc*/
# data-styled.g57[id="sc-xuUkR"]{content:"bMuyws,"}/*!sc*/
# .gaHJpd{font-size:var(--font-size-250);font-weight:var(--regular);line-height:var(--line-height-300);letter-spacing:-0.25px;text-align:center;color:var(--grey-250);margin-top:var(--spacing-24);}/*!sc*/
# data-styled.g58[id="sc-cvzDha"]{content:"gaHJpd,"}/*!sc*/
# .cvbYsJ{display:flex;flex-direction:column;}/*!sc*/
# @media (min-width: 767px){.cvbYsJ{flex-direction:row;gap:var(--spacing-32);}}/*!sc*/
# @media (min-width: 980px){.cvbYsJ{column-gap:80px;}}/*!sc*/
# data-styled.g59[id="sc-gKROGD"]{content:"cvbYsJ,"}/*!sc*/
# .jTBVQO{display:flex;flex-direction:column;gap:var(--spacing-8);}/*!sc*/
# data-styled.g60[id="sc-grBnJl"]{content:"jTBVQO,"}/*!sc*/
# .evCQfp{display:flex;column-gap:var(--spacing-8);}/*!sc*/
# data-styled.g61[id="sc-hrDJJk"]{content:"evCQfp,"}/*!sc*/
# .hNNdrt{list-style:none;display:flex;column-gap:var(--spacing-20);padding:var(--spacing-0);margin:var(--spacing-0);margin-bottom:var(--spacing-24);}/*!sc*/
# .hNNdrt li a{width:var(--icon-size-40);height:var(--icon-size-40);-webkit-transition:all 0.3s;-moz-transition:all 0.3s;-ms-transition:all 0.3s;-o-transition:all 0.3s;transition:all 0.3s;display:flex;justify-content:center;align-items:center;}/*!sc*/
# .hNNdrt li a>img{width:100%;height:100%;object-fit:cover;}/*!sc*/
# data-styled.g62[id="sc-jhhoqv"]{content:"hNNdrt,"}/*!sc*/
# .cMYQTW{list-style:none;display:flex;column-gap:var(--spacing-20);padding:var(--spacing-0);margin:var(--spacing-0);}/*!sc*/
# .cMYQTW li a{display:flex;width:auto;gap:var(--spacing-12);align-items:center;-webkit-transition:all 0.3s;-moz-transition:all 0.3s;-ms-transition:all 0.3s;-o-transition:all 0.3s;transition:all 0.3s;display:flex;justify-content:center;align-items:center;text-decoration:none;}/*!sc*/
# .cMYQTW li a>img{width:var(--icon-size-32);height:var(--icon-size-32);object-fit:cover;}/*!sc*/
# data-styled.g63[id="sc-khjKqu"]{content:"cMYQTW,"}/*!sc*/
# .kyBnvh{font-size:var(--font-size-250);font-weight:var(--medium);line-height:var(--line-height-300);color:var(--grey-500);margin:var(--spacing-0);}/*!sc*/
# data-styled.g64[id="sc-bDbPgR"]{content:"kyBnvh,"}/*!sc*/
# .jmuPFx{border-radius:var(--corner-radius-8);background-color:var(--sky-blue-50);box-shadow:none;}/*!sc*/
# .sc-cDelgQ .jmuPFx{border-bottom:1px solid var(--grey-100);}/*!sc*/
# data-styled.g66[id="sc-esHPOb"]{content:"jmuPFx,"}/*!sc*/
# .feedrw{display:flex;padding:var(--spacing-16) var(--spacing-16) var(--spacing-0);align-items:center;user-select:none;}/*!sc*/
# .feedrw >svg:first-child{margin-right:8px;flex-shrink:0;}/*!sc*/
# .feedrw >svg:last-child{padding:1px;transition:all 0.2s ease-in-out;flex-shrink:0;}/*!sc*/
# .jbWhFz{display:flex;padding:var(--spacing-16) var(--spacing-16) var(--spacing-0);align-items:center;user-select:none;padding-bottom:var(--spacing-16);}/*!sc*/
# .jbWhFz >svg:first-child{margin-right:8px;flex-shrink:0;}/*!sc*/
# .jbWhFz >svg:last-child{padding:1px;transition:all 0.2s ease-in-out;flex-shrink:0;}/*!sc*/
# data-styled.g67[id="sc-fsKlOa"]{content:"feedrw,jbWhFz,"}/*!sc*/
# .bZccbv{margin-top:var(--spacing-12);padding:var(--spacing-0) var(--spacing-16) var(--spacing-16);width:initial;margin-left:var(--spacing-28);margin-right:var(--spacing-28);color:var(--grey-900);}/*!sc*/
# data-styled.g68[id="sc-hNGPaV"]{content:"bZccbv,"}/*!sc*/
# .VEnmK{flex-grow:1;margin-left:var(--spacing-4);}/*!sc*/
# data-styled.g69[id="sc-iNJlaU"]{content:"VEnmK,"}/*!sc*/
# .eJrYUa{display:flex;align-items:center;justify-content:center;gap:var(--spacing-8);background-color:var(--grey-900);color:var(--base-white);padding:var(--spacing-8) var(--spacing-12);border-width:1.2px;border-style:solid;border-color:var(--grey-200);border-radius:var(--corner-radius-8);font-size:var(--font-size-sm);}/*!sc*/
# .eJrYUa:hover{background-color:var(--grey-900);color:var(--base-white);border-color:var(--grey-300);}/*!sc*/
# .eJrYUa:disabled{background-color:var(--grey-900);color:var(--grey-500);border-color:var(--grey-200);}/*!sc*/
# data-styled.g81[id="sc-jHofgq"]{content:"eJrYUa,"}/*!sc*/
# .cOIbco{padding:var(--spacing-4) var(--spacing-8);background-color:var(--grey-50);display:flex;justify-content:center;align-items:center;gap:var(--spacing-4);width:fit-content;height:24px;font-style:normal;border-radius:var(--corner-radius-4);}/*!sc*/
# @media (max-width: 767px){.cOIbco{height:20px;}}/*!sc*/
# data-styled.g82[id="sc-iRFtIJ"]{content:"cOIbco,"}/*!sc*/
# .bwryUk{position:absolute;top:0px;left:0px;z-index:30;}/*!sc*/
# data-styled.g83[id="sc-jRHPII"]{content:"bwryUk,"}/*!sc*/
# .bjmkBE{position:relative;top:8px;left:8px;}/*!sc*/
# data-styled.g84[id="sc-hWiVxH"]{content:"bjmkBE,"}/*!sc*/
# .ecMXep{background:linear-gradient(182deg, rgba(169, 185, 194, 0.50) 1.38%, rgba(255, 255, 255, 0.50) 91.7%);padding:var(--spacing-8) var(--spacing-8) var(--spacing-0);position:relative;overflow:hidden;display:flex;justify-content:center;}/*!sc*/
# .VOqvr{background:linear-gradient(180deg, rgba(245, 245, 245, 0.60) -13.78%, rgba(212, 180, 98, 0.60) 140.82%);padding:var(--spacing-8) var(--spacing-8) var(--spacing-0);position:relative;overflow:hidden;display:flex;justify-content:center;}/*!sc*/
# .VOqvr::after{content:"";width:728px;height:338px;position:absolute;left:50%;bottom:-300px;border-top:1px solid #D4B462;border-radius:50%;background:#fff;transform:translateX(-50%);}/*!sc*/
# data-styled.g85[id="sc-iWlrxG"]{content:"ecMXep,VOqvr,"}/*!sc*/
# .eJtgzc{width:220px;height:120px;display:flex;justify-content:center;position:relative;z-index:9;margin-top:-10px;transform:translateX(-12px);}/*!sc*/
# .eJtgzc>img{object-fit:contain;}/*!sc*/
# data-styled.g86[id="sc-igCFZZ"]{content:"eJtgzc,"}/*!sc*/
# .eqSvqy{width:var(--icon-size-20);height:var(--icon-size-20);position:absolute!important;top:var(--spacing-8);right:var(--spacing-8);display:flex;justify-content:center;align-items:center;z-index:9;content-visibility:auto;contain-intrinsic-height:auto var(--icon-size-20);}/*!sc*/
# .eqSvqy>img{width:100%;}/*!sc*/
# data-styled.g87[id="sc-jgFbZY"]{content:"eqSvqy,"}/*!sc*/
# .jcaLzI{position:relative;z-index:9;content-visibility:auto;display:flex;justify-content:space-between;flex-direction:column;row-gap:4px;height:60px;}/*!sc*/
# @media (max-width: 767px){.jcaLzI{height:52px;}}/*!sc*/
# data-styled.g88[id="sc-gUOWLT"]{content:"jcaLzI,"}/*!sc*/
# .kmyFGS{display:flex;column-gap:4px;padding:0px;margin:0 0 8px;}/*!sc*/
# data-styled.g89[id="sc-hURsLS"]{content:"kmyFGS,"}/*!sc*/
# .QrIzO{display:-webkit-box;-webkit-line-clamp:1;-webkit-box-orient:vertical;overflow:hidden;}/*!sc*/
# data-styled.g90[id="sc-gjHHYa"]{content:"QrIzO,"}/*!sc*/
# .ijyKos{position:relative;}/*!sc*/
# data-styled.g92[id="sc-ggPNws"]{content:"ijyKos,"}/*!sc*/
# .cShbCY{height:1px;width:100%;border-top:1px dashed #D6D6D6;margin:2px 0 8px;}/*!sc*/
# data-styled.g93[id="sc-kwhYVV"]{content:"cShbCY,"}/*!sc*/
# .kBPzWo{position:relative;}/*!sc*/
# data-styled.g94[id="sc-fyEUpq"]{content:"kBPzWo,"}/*!sc*/
# .QEYts{background-color:var(--base-white);display:flex;align-items:center;gap:var(--spacing-8);padding:0 var(--spacing-12);border-radius:var(--corner-radius-8);height:var(--size-40);box-sizing:border-box;border:1px solid var(--grey-200);opacity:1;contain:layout style;}/*!sc*/
# data-styled.g95[id="sc-jNXfOT"]{content:"QEYts,"}/*!sc*/
# .bKxLmy{flex:1;outline:none;border:none;font-size:var(--font-size-base);line-height:var(--font-line-height-base);color:var(--grey-900);width:100%;background:var(--base-white);transition:transform 0.2s,filter 0.3s;will-change:transform;}/*!sc*/
# .bKxLmy::placeholder{color:var(--grey-500);}/*!sc*/
# .bKxLmy:active,.bKxLmy:focus{outline:none;border:none;transform:scale(0.98);}/*!sc*/
# .bKxLmy:disabled{outline:none;border:none;color:var(--grey-300);}/*!sc*/
# data-styled.g96[id="sc-fvMZNI"]{content:"bKxLmy,"}/*!sc*/
# .cWkfzm{height:20px;width:20px;display:flex;justify-content:center;align-items:center;}/*!sc*/
# data-styled.g97[id="sc-jLflnl"]{content:"cWkfzm,"}/*!sc*/
# .kSfUox{position:absolute;opacity:0;width:0;height:0;}/*!sc*/
# data-styled.g98[id="sc-exkVDC"]{content:"kSfUox,"}/*!sc*/
# .ivbqC{display:flex;justify-content:center;align-items:center;width:var(--font-size-lg);height:var(--font-size-lg);background-color:var(--grey-50);border:1px solid var(--grey-200);border-radius:var(--corner-radius-4);}/*!sc*/
# .ivbqC svg{display:none;}/*!sc*/
# .sc-exkVDC:checked+.ivbqC,.sc-exkVDC:indeterminate+.ivbqC{background-color:var(--sky-blue-50);border-color:var(--sky-blue-700);}/*!sc*/
# .sc-exkVDC:checked+.ivbqC svg,.sc-exkVDC:indeterminate+.ivbqC svg{display:block;}/*!sc*/
# .sc-exkVDC:checked:active+.ivbqC,.sc-exkVDC:indeterminate:active+.ivbqC{background-color:var(--sky-blue-100);}/*!sc*/
# data-styled.g99[id="sc-iMDhdf"]{content:"ivbqC,"}/*!sc*/
# .cOuXEd{display:flex;align-items:center;cursor:pointer;width:fit-content;}/*!sc*/
# .cOuXEd .sc-exkVDC:checked+.sc-iMDhdf svg{display:block;}/*!sc*/
# data-styled.g100[id="sc-loAbOW"]{content:"cOuXEd,"}/*!sc*/
# .cVtTHw{padding:var(--spacing-4) var(--spacing-10);background-color:var(--base-white);border-width:1px;border-style:solid;border-color:var(--grey-200);border-radius:var(--corner-radius-8);display:flex;gap:var(--spacing-4);align-items:center;color:var(--grey-900);transition:transform 0.2s,filter 0.3s;}/*!sc*/
# .cVtTHw:active{transform:scale(0.98);filter:brightness(80%);}/*!sc*/
# .cVtTHw:disabled{background-color:var(--grey-50);border:none;color:var(--grey-300);}/*!sc*/
# data-styled.g101[id="sc-bPZXsP"]{content:"cVtTHw,"}/*!sc*/
# .kofkZt{display:flex;justify-content:center;align-items:center;width:var(--icon-size-16);height:var(--icon-size-16);}/*!sc*/
# data-styled.g102[id="sc-eteQWc"]{content:"kofkZt,"}/*!sc*/
# .cvGMfC{overflow:scroll;width:100%;}/*!sc*/
# .cvGMfC::-webkit-scrollbar{display:none;}/*!sc*/
# data-styled.g105[id="sc-SQOaL"]{content:"cvGMfC,"}/*!sc*/
# .kTZmPF{display:flex;flex-direction:row;gap:var(--spacing-8);background-color:var(--sky-blue-50);padding:var(--spacing-4);border-radius:var(--corner-radius-full);border-color:var(--stroke-none);}/*!sc*/
# data-styled.g106[id="sc-dvVHDY"]{content:"kTZmPF,"}/*!sc*/
# .bNHQLG{background-color:var(--base-white);border-radius:var(--corner-radius-full);padding:var(--spacing-4) var(--spacing-12);border-width:0px;border-style:solid;border-color:var(--stroke-none);display:flex;justify-content:center;align-items:center;gap:var(--spacing-0);min-width:fit-content;cursor:pointer;width:100%;transition:transform 0.2s,filter 0.3s;}/*!sc*/
# .bNHQLG:active{transform:scale(0.98);filter:brightness(80%);}/*!sc*/
# .bqGGDD{background-color:var(--sky-blue-50);border-radius:var(--corner-radius-full);padding:var(--spacing-4) var(--spacing-12);border-width:0px;border-style:solid;border-color:var(--stroke-none);display:flex;justify-content:center;align-items:center;gap:var(--spacing-0);min-width:fit-content;cursor:pointer;width:100%;transition:transform 0.2s,filter 0.3s;}/*!sc*/
# .bqGGDD:active{transform:scale(0.98);filter:brightness(80%);}/*!sc*/
# data-styled.g107[id="sc-fmRmGN"]{content:"bNHQLG,bqGGDD,"}/*!sc*/
# .iyZhgA{display:flex;flex-direction:column;align-items:center;justify-content:center;gap:var(--spacing-8);flex:auto;width:fit-content;}/*!sc*/
# data-styled.g108[id="sc-bTwLay"]{content:"iyZhgA,"}/*!sc*/
# .fpjwkc p{display:flex;}/*!sc*/
# data-styled.g109[id="sc-dKsqdn"]{content:"fpjwkc,"}/*!sc*/
# .cnYrCA{display:flex;flex-direction:column;padding:var(--spacing-24) var(--spacing-0) 68px var(--spacing-12);}/*!sc*/
# data-styled.g233[id="sc-iuzJEE"]{content:"cnYrCA,"}/*!sc*/
# .TOqh{display:grid;grid-auto-flow:column;grid-template-columns:repeat(3, minmax(240px, 1fr));grid-template-rows:repeat(6, minmax(var(--spacing-20), 240px));grid-gap:10px;padding-top:var(--spacing-20);height:216px;}/*!sc*/
# data-styled.g234[id="sc-kbjXBD"]{content:"TOqh,"}/*!sc*/
# .cCojsX{width:240px;margin-bottom:var(--spacing-24);margin-right:var(--spacing-48);}/*!sc*/
# data-styled.g235[id="sc-gJLVjK"]{content:"cCojsX,"}/*!sc*/
# .dWUNwb{text-decoration:none;display:flex;justify-content:space-between;align-items:center;}/*!sc*/
# data-styled.g236[id="sc-jgUaRe"]{content:"dWUNwb,"}/*!sc*/
# .iEVaMT{flex-direction:column;flex-grow:3;padding:var(--spacing-20) var(--spacing-0) var(--spacing-20) 36px;display:block;min-height:360px;}/*!sc*/
# .iqpTpk{flex-direction:column;flex-grow:3;padding:var(--spacing-20) var(--spacing-0) var(--spacing-20) 36px;display:none;min-height:360px;}/*!sc*/
# data-styled.g237[id="sc-guCnPD"]{content:"iEVaMT,iqpTpk,"}/*!sc*/
# .gYGWpD{display:grid;grid-auto-flow:column;grid-template-columns:repeat(3, minmax(240px, 1fr));grid-template-rows:repeat(5, minmax(var(--spacing-20), 240px));grid-gap:10px;margin-top:28px;max-height:200px;overflow:hidden;}/*!sc*/
# data-styled.g238[id="sc-ctNHPE"]{content:"gYGWpD,"}/*!sc*/
# .bPgBXO{display:flex;flex-direction:column;height:100%;justify-content:space-between;}/*!sc*/
# data-styled.g239[id="sc-kWREmZ"]{content:"bPgBXO,"}/*!sc*/
# .bbgkkk{min-width:240px;max-width:300px;margin-bottom:var(--spacing-24);margin-right:var(--spacing-48);text-decoration:none;}/*!sc*/
# data-styled.g240[id="sc-ijKRza"]{content:"bbgkkk,"}/*!sc*/
# .jijdoH{display:flex;justify-content:space-between;align-items:baseline;}/*!sc*/
# data-styled.g241[id="sc-fxtexz"]{content:"jijdoH,"}/*!sc*/
# .liEuih{display:flex;flex-wrap:wrap;min-height:200px;}/*!sc*/
# data-styled.g242[id="sc-bwEyxA"]{content:"liEuih,"}/*!sc*/
# .hayqms{margin:var(--spacing-20) var(--spacing-20) var(--spacing-0) var(--spacing-0);}/*!sc*/
# data-styled.g243[id="sc-jZIuUV"]{content:"hayqms,"}/*!sc*/
# .ddgTgT{display:flex;align-items:center;justify-content:flex-end;margin-bottom:var(--spacing-24);}/*!sc*/
# data-styled.g244[id="sc-lbmtBC"]{content:"ddgTgT,"}/*!sc*/
# .UhiBx{display:grid;grid-template-columns:auto auto auto;gap:var(--spacing-32);}/*!sc*/
# data-styled.g245[id="sc-ioUGAb"]{content:"UhiBx,"}/*!sc*/
# .hQJyJP{margin-right:var(--spacing-4);}/*!sc*/
# data-styled.g246[id="sc-eGiQBl"]{content:"hQJyJP,"}/*!sc*/
# .ceUhcO{min-height:var(--size-16);min-width:var(--size-16);}/*!sc*/
# data-styled.g247[id="sc-bBWtns"]{content:"ceUhcO,"}/*!sc*/
# .dxpPuJ{background-color:var(--grey-50);padding-top:var(--spacing-12);padding-left:var(--spacing-12);padding-bottom:14px;border-radius:var(--spacing-12);flex-grow:1;min-width:368px;max-width:368px;}/*!sc*/
# data-styled.g248[id="sc-dlcTKf"]{content:"dxpPuJ,"}/*!sc*/
# .hZrhPh{display:flex;flex-direction:column;justify-content:space-between;}/*!sc*/
# data-styled.g249[id="sc-gQwwm"]{content:"hZrhPh,"}/*!sc*/
# .duGZAs{height:34px;display:flex;align-items:center;justify-content:space-between;margin:var(--spacing-0) var(--spacing-16) var(--spacing-12) var(--spacing-12);}/*!sc*/
# data-styled.g250[id="sc-fffiAB"]{content:"duGZAs,"}/*!sc*/
# .gqRgP{background-color:var(--base-white);border-top-left-radius:var(--spacing-8) var(--spacing-8);border-bottom-left-radius:var(--spacing-8) var(--spacing-8);align-items:center;display:flex;justify-content:space-between;padding:var(--spacing-10) var(--spacing-16) var(--spacing-10) var(--spacing-10);}/*!sc*/
# .gqRgP:not(:last-child){margin-bottom:var(--spacing-8);}/*!sc*/
# .kkmWtZ{background-color:var(--grey-50);align-items:center;display:flex;justify-content:space-between;padding:var(--spacing-10) var(--spacing-16) var(--spacing-10) var(--spacing-10);}/*!sc*/
# .kkmWtZ:not(:last-child){margin-bottom:var(--spacing-8);}/*!sc*/
# data-styled.g251[id="sc-caSLmI"]{content:"gqRgP,kkmWtZ,"}/*!sc*/
# .haGgJZ{padding:var(--spacing-10) var(--spacing-16) var(--spacing-10) var(--spacing-10);}/*!sc*/
# data-styled.g252[id="sc-dJZlJv"]{content:"haGgJZ,"}/*!sc*/
# .kAZhRG{display:flex;justify-content:space-between;margin-top:var(--spacing-8);text-decoration:none;}/*!sc*/
# data-styled.g253[id="sc-FMOvC"]{content:"kAZhRG,"}/*!sc*/
# .KdpIG{display:flex;}/*!sc*/
# data-styled.g254[id="sc-gABjlJ"]{content:"KdpIG,"}/*!sc*/
# .kHEIGr{position:absolute;opacity:0;width:0;height:0;}/*!sc*/
# data-styled.g255[id="sc-dwoLXQ"]{content:"kHEIGr,"}/*!sc*/
# .cLPdKL{display:flex;justify-content:center;align-items:center;width:var(--font-size-lg);height:var(--font-size-lg);background-color:var(--grey-50);border:1px solid var(--grey-200);border-radius:var(--corner-radius-full);}/*!sc*/
# .cLPdKL svg{display:none;}/*!sc*/
# .sc-dwoLXQ:checked+.cLPdKL{background-color:var(--sky-blue-50);border-color:var(--sky-blue-700);}/*!sc*/
# .sc-dwoLXQ:checked+.cLPdKL svg{display:block;}/*!sc*/
# .sc-dwoLXQ:checked:active+.cLPdKL{background-color:var(--sky-blue-100);}/*!sc*/
# data-styled.g256[id="sc-fGlmBk"]{content:"cLPdKL,"}/*!sc*/
# .csZivd{display:flex;align-items:center;cursor:pointer;width:fit-content;}/*!sc*/
# .csZivd .sc-dwoLXQ:checked+.sc-fGlmBk svg{display:block;}/*!sc*/
# data-styled.g257[id="sc-cTTzzJ"]{content:"csZivd,"}/*!sc*/
# .bcvqWC{height:24px;width:24px;display:flex;align-items:center;justify-content:center;background-color:transparent;}/*!sc*/
# data-styled.g258[id="sc-elfpKe"]{content:"bcvqWC,"}/*!sc*/
# </style><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/33617-b0f6456d4ecc2bd8.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/43860-62503c3b8d053787.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/44392-9f6b17f0eab5803e.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/58395-31a253a008191c6f.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/70408-a0cc35f452af9171.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/45275-be95b7db50b4769d.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/68656-2a430c2c2d678bf4.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/69535-1d64f4a42551d16e.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/17310-c625fd4948230f5e.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/66233-d08fd3f1114dc6d9.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/59144-c31d300c4b999cdd.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/79940-e64ac3533648b6b6.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/4616-8bc681753f40224a.js"></script><script async="" src="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/chunks/app/desktop/buy-used-cars-listing/page-6fb969683d68499c.js"></script><link as="image" fetchpriority="high" href="https://media.cars24.com/india/cms/prod/banners/root/2025/01/27/68f8b3f8-dea1-42c5-b47d-02237a8e886a-026db392-3597-4935-b52a-ed849601f6dc-luxe-desktop.webp?w=100&amp;dpr=3" rel="preload"/><link as="image" href="https://media.cars24.com/india/car-catalog/icons_13122024/luxe.png" rel="preload"/><link as="style" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/94b1229db2e44804.css" rel="preload"/><link as="style" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/e6f355622f4091f5.css" rel="preload"/><link as="style" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/47cde6cb9ef97f48.css" rel="preload"/><link as="style" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/16eea47486a09540.css" rel="preload"/><link as="style" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/b6e135a5e6c1b25b.css" rel="preload"/><link as="style" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/0723399071a714ca.css" rel="preload"/><link as="style" href="https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/0d546368889e56e7.css" rel="preload"/><div hidden="" id="S:1"><header class="styles_headerWrapper___Hepv null"><div class="container styles_headerContainer__zDx_u"><div class="styles_leftNavWrapper__opqQD"><div class="styles_logoWrapper___J4WM"><a class="d-inline-block styles_logo__6YcJI" href="/"> <img alt="logo" data-nimg="1" decoding="async" height="39" loading="lazy" src="https://media.cars24.com/cars24/seo/static/1_20230830_1693395013.png" style="color:transparent" width="80"/></a></div><div class="styles_dropdownWrapper___CFX_"><div class="styles_cityName__VUTON"><img alt="city" class="mr-2" data-nimg="1" decoding="async" height="18" loading="lazy" s ...
# $RR=function(r,t,w){for(var u=$RC,n=$RM,p=new Map,q=document,g,b,h=q.querySelectorAll("link[data-precedence],style[data-precedence]"),v=[],k=0;b=h[k++];)"not all"===b.getAttribute("media")?v.push(b):("LINK"===b.tagName&&n.set(b.getAttribute("href"),b),p.set(b.dataset.precedence,g=b));b=0;h=[];var l,a;for(k=!0;;){if(k){var f=w[b++];if(!f){k=!1;b=0;continue}var c=!1,m=0;var d=f[m++];if(a=n.get(d)){var e=a._p;c=!0}else{a=q.createElement("link");a.href=d;a.rel="stylesheet";for(a.dataset.precedence=
# l=f[m++];e=f[m++];)a.setAttribute(e,f[m++]);e=a._p=new Promise(function(x,y){a.onload=x;a.onerror=y});n.set(d,a)}d=a.getAttribute("media");!e||"l"===e.s||d&&!matchMedia(d).matches||h.push(e);if(c)continue}else{a=v[b++];if(!a)break;l=a.getAttribute("data-precedence");a.removeAttribute("media")}c=p.get(l)||g;c===g&&(g=a);p.set(l,a);c?c.parentNode.insertBefore(a,c.nextSibling):(c=q.head,c.insertBefore(a,c.firstChild))}Promise.all(h).then(u.bind(null,r,t,""),u.bind(null,r,t,"Resource failed to load"))};$RR("B:0","S:0",[["https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/94b1229db2e44804.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/e6f355622f4091f5.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/47cde6cb9ef97f48.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/16eea47486a09540.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/b6e135a5e6c1b25b.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/0723399071a714ca.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250515163138/_next/static/css/0d546368889e56e7.css","dynamic","as","style"]])</script></body></html>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
result = soup.find_all('a', {'class':'styles_carCardWrapper__sXLIp'})

# %%
len(result)
# Out:
# 14

# %%
name_part = result[0].find('span', {'class':'sc-braxZu kjFjan'}).get_text().split()[1:]
full_name = " ".join(name_part)
full_name
# Out:
# 'Toyota Camry'

# %%
year = result[0].find('span', {'class':'sc-braxZu kjFjan'}).get_text().split()[0]
year
# Out:
# '2016'

# %%
km = result[0].find_all('p', {'class': 'sc-braxZu kvfdZL'})
km[0].get_text()
# Out:
# '69.25k km'

# %%
e = result[0].find_all('p', {'class': 'sc-braxZu kvfdZL'})
e[1].get_text()
# Out:
# 'Hybrid'

# %%
e = result[0].find_all('p', {'class': 'sc-braxZu kvfdZL'})
e[2].get_text()
# Out:
# 'Auto'

# %%
result[0].find('p', {'class': 'sc-braxZu cyPhJl'}).get_text()
# Out:
# '₹10.85 lakh'

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests


car_make = []
car_model = []
kilometers = []
fuel_type = []
transmission = []
price = []
location = []


url = 'https://www.cars24.com/buy-used-maruti-cars-mumbai/?sort=bestmatch&serveWarrantyCount=true&listingSource=TabFilter&storeCityId=2378'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0 Safari/537.36'
}

response = requests.get(url, headers=headers)

if response.status_code != 200:
    print("Failed to retrieve page:", response.status_code)
    exit()

soup = BeautifulSoup(response.text, 'html.parser')

car_cards = soup.find_all('a', {'class': 'styles_carCardWrapper__sXLIp'})[:9]

for card in car_cards:
    
    title_span = card.find('span', {'class': 'sc-braxZu kjFjan'})
    if title_span:
        full_title = title_span.get_text().strip()
        parts = full_title.split()
        if len(parts) >= 3:
            car_make.append(parts[1])
            car_model.append(' '.join(parts[2:]))
        else:
            car_make.append('N/A')
            car_model.append('N/A')
    else:
        car_make.append('N/A')
        car_model.append('N/A')

    specs = card.find_all('p', {'class': 'sc-braxZu kvfdZL'})
    kilometers.append(specs[0].get_text().strip() if len(specs) > 0 else 'N/A')
    fuel_type.append(specs[1].get_text().strip() if len(specs) > 1 else 'N/A')
    transmission.append(specs[2].get_text().strip() if len(specs) > 2 else 'N/A')

   
    price_p = card.find('p', {'class': 'sc-braxZu cyPhJl'})
    price.append(price_p.get_text().strip() if price_p else 'N/A')

    
    loc_p = card.find('p', {'class': 'sc-braxZu dLJHhZ'}) 
    if not loc_p:
        loc_p = card.find('span', {'class': 'styles_cityName__location'})  
    if not loc_p:
        
        found_location = None
        for tag in card.find_all(['p', 'span']):
            text = tag.get_text().strip()
            if 'Mumbai' in text or 'Location' in text or 'City' in text:
                found_location = text
                break
        location.append(found_location if found_location else 'N/A')
    else:
        location.append(loc_p.get_text().strip())


df = pd.DataFrame({
    ' Car Make': car_make,
    'Model': car_model,
    'Kilometers Driven': kilometers,
    'Fuel Type': fuel_type,
    'Transmission Type': transmission,
    'Price': price,
    'Location': location
})

df.to_csv('cars24_maruti_mumbai_9.csv', index=False)
print("CSV saved as cars24_maruti_mumbai_9.csv")
# Out:
# CSV saved as cars24_maruti_mumbai_9.csv
